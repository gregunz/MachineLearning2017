# %%
import csv
import numpy as np

# %%
glob("data/tuning/best_mult/*_2.csv")[0]
# Out:
# 'data/tuning/best_mult\\best_mult_2888_2.csv'

# %%
filenames("mult", 3)
# Out:
# ['data/tuning/best_mult\\best_mult_4793_0.csv',
#  'data/tuning/best_mult\\best_mult_7440_1.csv',
#  'data/tuning/best_mult\\best_mult_2888_2.csv']

# %%
scores, pairs = extract_data('data/tuning/best_mult\\best_mult_2888_2.csv')

# %%
(np.array(scores) > 0.05).sum()
# Out:
# 0

# %%
build_combinations("mult", 0.001, 3)
# Out:
# [[(1, 22),
#   (1, 24),
#   (1, 37),
#   (1, 39),
#   (4, 24),
#   (4, 39),
#   (7, 13),
#   (7, 16),
#   (7, 28),
#   (7, 31),
#   (7, 43),
#   (8, 28),
#   (8, 43),
#   (13, 22),
#   (13, 37),
#   (16, 18),
#   (16, 20),
#   (16, 21),
#   (16, 22),
#   (16, 24),
#   (16, 33),
#   (16, 35),
#   (16, 36),
#   (16, 37),
#   (16, 39),
#   (18, 28),
#   (18, 31),
#   (18, 43),
#   (20, 28),
#   (20, 31),
#   (20, 43),
#   (21, 31),
#   (22, 28),
#   (22, 31),
#   (22, 43),
#   (23, 28),
#   (23, 43),
#   (24, 28),
#   (24, 31),
#   (24, 43),
#   (28, 33),
#   (28, 35),
#   (28, 37),
#   (28, 38),
#   (28, 39),
#   (31, 33),
#   (31, 35),
#   (31, 36),
#   (31, 37),
#   (31, 39),
#   (33, 43),
#   (35, 43),
#   (37, 43),
#   (38, 43),
#   (39, 43)],
#  [(0, 1),
#   (0, 4),
#   (0, 11),
#   (0, 18),
#   (0, 19),
#   (0, 20),
#   (0, 21),
#   (0, 22),
#   (0, 29),
#   (0, 36),
#   (0, 37),
#   (0, 38),
#   (0, 39),
#   (0, 40),
#   (0, 47),
#   (1, 4),
#   (1, 13),
#   (1, 18),
# ...

# %%
build_xs_mask("xs_mix", 0.0, 3)
# Out:
# [[1, 8, 13, 17, 19, 23, 27, 28, 32, 34, 38, 42, 43],
#  [5, 8, 14, 18, 26, 29, 36, 44, 47],
#  [10,
#   18,
#   21,
#   27,
#   28,
#   29,
#   34,
#   35,
#   36,
#   38,
#   43,
#   45,
#   52,
#   53,
#   54,
#   59,
#   60,
#   61,
#   63,
#   68,
#   70]]
